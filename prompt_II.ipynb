# %% [markdown]
# # What drives the price of a car?
#
# ![](images/kurt.jpeg)

# %% [markdown]
# **OVERVIEW**
#
# In this application, you will explore a dataset from kaggle. The original dataset contained information on 3 million used cars. The provided dataset contains information on 426K cars to ensure speed of processing.  Your goal is to understand what factors make a car more or less expensive.  As a result of your analysis, you should provide clear recommendations to your client -- a used car dealership -- as to what consumers value in a used car.

# %% [markdown]
# ### CRISP-DM Framework
#
# <center>
#     <img src = images/crisp.png width = 50%/>
# </center>
#
#
# To frame the task, throughout our practical applications we will refer back to a standard process in industry for data projects called CRISP-DM.  This process provides a framework for working through a data problem.  Your first step in this application will be to read through a brief overview of CRISP-DM [here](https://mo-pcco.s3.us-east-1.amazonaws.com/BH-PCMLAI/module_11/readings_starter.zip).  After reading the overview, answer the questions below.

# %% [markdown]
# ### Business Understanding
#
# From a business perspective, we are tasked with identifying key drivers for used car prices.  In the CRISP-DM overview, we are asked to convert this business framing to a data problem definition.  Using a few sentences, reframe the task as a data task with the appropriate technical vocabulary.

# %% [markdown]
#     I plan to utilize a dataset with details of 426,000 cars to develop a linear regression model. This model will aid our client, a used car dealership, in accurately predicting the prices of used cars.
#
#     This model will play a crucial role in pinpointing the main factors that impact used car prices. By doing so, it will provide a deeper understanding of how these factors influence the pricing of cars in the market.

# %% [markdown]
# ### Data Understanding
#
# After considering the business understanding, we want to get familiar with our data.  Write down some steps that you would take to get to know the dataset and identify any quality issues within.  Take time to get to know the dataset and explore what information it contains and how this could be used to inform your business understanding.

# %% [markdown]
#     1.We need to understand whether particular columns have any  missing values. If so then, eliminate those columns from our model.
#     2.As it is price predction, so 'price' column will be the target column to predict.
#     3.Some columns (e.g. 'year', 'odometer') contain numerical values, so we will just keep them as is. The column 'cylinders' can be converted easily to numerical values.
#     4.Some columns contain categorical features, including 'manufacturer', 'model', 'fuel', 'title_status','transmission','drive','type','paint_color', and 'state'. We can use one-hot encoding to convert them into numerical values.
#     5.Some columns contain ordinal features, including 'conditions' and 'size', we can use the ordinal encoder to transform them into numerical features.
#     6.Column 'VIN' seems irrelevant for this activity of prediction, so planning to eliminate it from the dataframe.

# %% [markdown]
# ### Data Preparation
#
#     After our initial exploration and fine tuning of the business understanding, it is time to construct our final dataset prior to modeling.  Here, we want to make sure to handle any integrity issues and cleaning, the engineering of new features, any transformations that we believe should happen (scaling, logarithms, normalization, etc.), and general preparation for modeling with `sklearn`.

# %%
# Libraries imported
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline

# %%
#Load the vahicle data to data frame
df=pd.read_csv("./data/vehicles.csv")

# %%
# check the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 18 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   region        426880 non-null  object
#  2   price         426880 non-null  int64
#  3   year          425675 non-null  float64
#  4   manufacturer  409234 non-null  object
#  5   model         421603 non-null  object
#  6   condition     252776 non-null  object
#  7   cylinders     249202 non-null  object
#  8   fuel          423867 non-null  object
#  9   odometer      422480 non-null  float64
#  10  title_status  418638 non-null  object
#  11  transmission  424324 non-null  object
#  12  VIN           265838 non-null  object
#  13  drive         296313 non-null  object
#  14  size          120519 non-null  object
#  15  type          334022 non-null  object
#  16  paint_color   296677 non-null  object
# ...

# %%
# check number of unique values for each column
df.nunique()
# Out:
# id              426880
# region             404
# price            15655
# year               114
# manufacturer        42
# model            29649
# condition            6
# cylinders            8
# fuel                 5
# odometer        104870
# title_status         6
# transmission         3
# VIN             118246
# drive                3
# size                 4
# type                13
# paint_color         12
# state               51
# dtype: int64

# %%
#Number of null values per column
df.isnull().sum()
# Out:
# id                   0
# region               0
# price                0
# year              1205
# manufacturer     17646
# model             5277
# condition       174104
# cylinders       177678
# fuel              3013
# odometer          4400
# title_status      8242
# transmission      2556
# VIN             161042
# drive           130567
# size            306361
# type             92858
# paint_color     130203
# state                0
# dtype: int64

# %%
# droping the columns:  "size"[because lots of values are missing in this column]
#                       "VIN"[Irrilivant for prediction]
#                       "id" because they are irrelevant to car price prediction and analysis
df=df.drop(columns=['size','VIN','id'],axis=1)

# %%
# droping columns "region" and "model"as these categorical column have too many unique values.
df=df.drop(columns=['region','model'],axis=1)

# %%
# drop the rows with missing values
df=df.dropna()
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 117169 entries, 31 to 426878
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   price         117169 non-null  int64
#  1   year          117169 non-null  float64
#  2   manufacturer  117169 non-null  object
#  3   condition     117169 non-null  object
#  4   cylinders     117169 non-null  object
#  5   fuel          117169 non-null  object
#  6   odometer      117169 non-null  float64
#  7   title_status  117169 non-null  object
#  8   transmission  117169 non-null  object
#  9   drive         117169 non-null  object
#  10  type          117169 non-null  object
#  11  paint_color   117169 non-null  object
#  12  state         117169 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 12.5+ MB
#         price    year manufacturer  condition    cylinders fuel  odometer  \
# ...

# %%
# print out the unique values for each ordinal feature
print(df.condition.unique())
print(df.cylinders.unique())
# Out:
# ['excellent' 'good' 'like new' 'new' 'fair' 'salvage']
# ['6 cylinders' '8 cylinders' '4 cylinders' '5 cylinders' '10 cylinders'
#  '3 cylinders' 'other' '12 cylinders']

# %%
# Removing outliners by defining the range for numerial columns and rename the dataframe to df1
df1=df[(df['price'] <200000) & (df['price']>400)& (df['odometer'] <250000)];

# %%
df.query('price ==0').count()
# Out:
# price           4373
# year            4373
# manufacturer    4373
# condition       4373
# cylinders       4373
# fuel            4373
# odometer        4373
# title_status    4373
# transmission    4373
# drive           4373
# type            4373
# paint_color     4373
# state           4373
# dtype: int64

# %%
df = df.sort_values('price',ascending=False).dropna()
fig, ax = plt.subplots()
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
sns.set(rc={"figure.figsize":(10, 12)}) #width=10, height=4

sns.barplot(data=df,x='manufacturer', y='price')
plt.xticks(rotation=90)
plt.title('Sales price by manufacturer')
plt.show()

# %%
df = df.sort_values('price',ascending=False)
fig, ax = plt.subplots()
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
sns.set(rc={"figure.figsize":(10, 12)}) #width=10, height=12

sns.barplot(x='paint_color', y='price' ,data=df)
plt.xticks(rotation=85)
plt.title('Sales price by paint color')
plt.show()
plt.savefig('Images/SalesPaintColor.png')

# %%
df = df.sort_values('price',ascending=False)
fig, ax = plt.subplots()
ax.yaxis.get_major_formatter().set_scientific(False)
ax.yaxis.get_major_formatter().set_useOffset(False)
sns.set(rc={"figure.figsize":(10, 12)}) #width=10, height=12

sns.barplot(x='transmission', y='price' ,data=df)
plt.xticks(rotation=85)
plt.title('Sales price by transmission')
plt.show()
plt.savefig('Images/SalesPaintColor.png')

# %%
# Slitting the dataset
y=df1['price'].astype(float);
X=df1.drop(columns='price', axis=1)

# %%
# covert the normal features to numerical features
norminal_column=['manufacturer','fuel', 'title_status','transmission','drive','type','paint_color','state'];
new_X =  pd.get_dummies(X, columns=norminal_column)
print(new_X)
# Out:
#           year  condition    cylinders  odometer  manufacturer_acura  \
# 31      2013.0  excellent  6 cylinders  128000.0               False
# 32      2012.0       good  8 cylinders   68696.0               False
# 33      2016.0       good  6 cylinders   29499.0               False
# 34      2019.0  excellent  6 cylinders   43000.0               False
# 35      2016.0       good  6 cylinders   17302.0               False
# ...        ...        ...          ...       ...                 ...
# 426859  2020.0       good  6 cylinders    7701.0               False
# 426860  2017.0       good  8 cylinders   41664.0               False
# 426866  2016.0       good  8 cylinders   55612.0               False
# 426874  2018.0       good  6 cylinders   30814.0               False
# 426878  2018.0       good  6 cylinders   30112.0               False
#
#         manufacturer_alfa-romeo  manufacturer_aston-martin  manufacturer_audi  \
# ...

# %%
# conver the ordinal features to numerical featurs using map function

new_X['condition'] =  new_X['condition'] .map({'new':5, 'like new':4,'excellent':3, 'good':2,'fair':1, 'salvage':0})
new_X['cylinders'] =  new_X['cylinders'] .map({'6 cylinders':6, '8 cylinders':8,'4 cylinders':4, '5 cylinders':5,'10 cylinders':10, '3 cylinders':3,'12 cylinders':12, 'other':8})

# %%
new_X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108656 entries, 31 to 426878
# Columns: 139 entries, year to state_wy
# dtypes: bool(135), float64(2), int64(2)
# memory usage: 18.1 MB

# %% [markdown]
#     Logarithmic transformation is a widely used mathematical technique to reduce the skewness in the distribution of a variable. By applying a logarithmic transformation to the target column, such as the used car price, we aim to make the distribution more symmetric and easier to analyze. This transformation can help address any issues related to skewed data and improve the overall interpretability of the target variable.![image.png](attachment:image.png)

# %%
# plot histogram of the target column using linear scale or logarithmic scale
plt.subplot(1,3,1)
plt.hist(y)
plt.xlabel('Used car price')
plt.ylabel('Counts')
plt.subplot(1,3,3)
plt.hist(np.log(y))

plt.xlabel('Logarithmic used car price')
plt.ylabel('Counts')
# Out:
# Text(0, 0.5, 'Counts')

# %% [markdown]
# ### Modeling
#
# With your (almost?) final dataset in hand, it is now time to build some models.  Here, you should build a number of different regression models with the price as the target.  In building your models, you should explore different parameters and be sure to cross-validate your findings.

# %%
#spliting the price data into training  and test set
X_train, X_test, y_train, y_test = train_test_split(new_X, np.log(y), random_state = 42);

# %%
# GridSearchCV to find the optimal value for alpha in the Ridge regression model
ridge_param_dict = {'ridge__alpha': np.logspace(0, 3, 50)}

# build a pipeline and standardize the values first
ridge_pipe = Pipeline([('scaler', StandardScaler()), 
                      ('ridge', Ridge())])
ridge_grid = GridSearchCV(ridge_pipe, param_grid=ridge_param_dict)
ridge_grid.fit(X_train, y_train)
ridge_train_preds = ridge_grid.predict(X_train)
ridge_test_preds = ridge_grid.predict(X_test)

ridge_train_mse = mean_squared_error(y_train, ridge_train_preds)
ridge_test_mse = mean_squared_error(y_test, ridge_test_preds)

# ANSWER CHECK
print(f'Train MSE: {ridge_train_mse}')
print(f'Test MSE: {ridge_test_mse}')
# Out:
# Train MSE: 0.24703747505058374
# Test MSE: 0.24841063478307057

# %%
ridge_pipe
# Out:
# Pipeline(steps=[('scaler', StandardScaler()), ('ridge', Ridge())])

# %%
# Actual car prices vs Predicted price  afterprediction by redge regression
plt.plot(y_test,ridge_test_preds,'bo', markersize=1)
plt.xlabel('Logarithmic predicted car prices')
plt.ylabel('Logarithmic actual car prices')
plt.title('Ridge regression model')
# plot the diagonal line
plt.plot([6 ,12],[6,12], 'y-')

# %%
best_estimator = ridge_grid.best_estimator_
best_model = ridge_grid.best_estimator_.named_steps['ridge']
feature_names = X_train.columns
coefs_ridge = best_model.coef_

# %%
# extract the value alpha for best model
best_model
# Out:
# Ridge(alpha=138.94954943731375)

# %%
pd1=pd.DataFrame.from_dict({'feature_names':feature_names,'coef':coefs_ridge})
pd1['abs_coef']=abs(pd1.coef)

# %%
# sort the coefficien
pd1=pd1.sort_values(by='abs_coef', ascending=False)
pd1.head(25)
# Out:
#               feature_names      coef  abs_coef
# 3                  odometer -0.409705  0.409705
# 0                      year  0.210006  0.210006
# 2                 cylinders  0.145296  0.145296
# 1                 condition  0.129423  0.129423
# 61                drive_fwd -0.082113  0.082113
# 46              fuel_diesel  0.080682  0.080682
# 72               type_sedan -0.078240  0.078240
# 73               type_truck  0.074226  0.074226
# 59       transmission_other  0.064628  0.064628
# 60                drive_4wd  0.061451  0.061451
# 48                 fuel_gas -0.056256  0.056256
# 43      manufacturer_toyota  0.048968  0.048968
# 57   transmission_automatic -0.046086  0.046086
# 27       manufacturer_lexus  0.035673  0.035673
# 67           type_hatchback -0.033890  0.033890
# 71              type_pickup  0.031879  0.031879
# 31     manufacturer_mercury -0.029287  0.029287
# 123                state_oh -0.029161  0.029161
# 12    manufacturer_chrysler -0.028858  0.028858
# ...

# %%
# Using GridSearchCV to find the optimal value  using Lasso regression model
lasso_param_dict = {'lasso__alpha': np.logspace(-1.5, 2, 50)}
# build a pipeline and standardize the values first
lasso_pipe = Pipeline([('scaler', StandardScaler()), 
                      ('lasso', Lasso())])
lasso_grid = GridSearchCV(lasso_pipe, param_grid=lasso_param_dict)
lasso_grid.fit(X_train, y_train)
lasso_train_preds = lasso_grid.predict(X_train)
lasso_test_preds = lasso_grid.predict(X_test)
lasso_train_mse = mean_squared_error(y_train, lasso_train_preds)
lasso_test_mse = mean_squared_error(y_test, lasso_test_preds)

# ANSWER CHECK
print(f'Train MSE: {lasso_train_mse}')
print(f'Test MSE: {lasso_test_mse}')
lasso_pipe
# Out:
# Train MSE: 0.27448017530158586
# Test MSE: 0.2762903162054993
# Pipeline(steps=[('scaler', StandardScaler()), ('lasso', Lasso())])

# %%
best_estimator1 = lasso_grid.best_estimator_
best_model1 = lasso_grid.best_estimator_.named_steps['lasso']
feature_names = X_train.columns
coefs_lasso = best_model1.coef_

# %%
# extract the best model's alpha value
best_model1
# Out:
# Lasso(alpha=0.03162277660168379)

# %%
# plot the actual car prices agaisnt the predicted car price in test set
plt.plot(y_test,lasso_test_preds,'bo',markersize=1)
plt.xlabel('Logarithmic predicted car prices')
plt.ylabel('Logarithmic actual car prices')
plt.title('Lasso regression model')
# plot the diagonal line
plt.plot([6 ,12],[6,12], 'g-')

# %%
pd2=pd.DataFrame.from_dict({'feature_names':feature_names,'coef':coefs_lasso})
pd2['abs_coef']=abs(pd2.coef)

# %%
# sort the coefficient based on their absolute values, from largest to smallest
pd2=pd2.sort_values(by='abs_coef', ascending=False)
pd2.head(25)
# Out:
#               feature_names      coef  abs_coef
# 3                  odometer -0.398770  0.398770
# 0                      year  0.193426  0.193426
# 2                 cylinders  0.143772  0.143772
# 61                drive_fwd -0.130800  0.130800
# 1                 condition  0.095732  0.095732
# 46              fuel_diesel  0.085774  0.085774
# 59       transmission_other  0.083539  0.083539
# 72               type_sedan -0.063103  0.063103
# 73               type_truck  0.049357  0.049357
# 48                 fuel_gas -0.027798  0.027798
# 60                drive_4wd  0.016185  0.016185
# 43      manufacturer_toyota  0.015534  0.015534
# 51       title_status_clean  0.008950  0.008950
# 71              type_pickup  0.006936  0.006936
# 67           type_hatchback -0.006916  0.006916
# 57   transmission_automatic -0.004412  0.004412
# 31     manufacturer_mercury -0.003836  0.003836
# 123                state_oh -0.003019  0.003019
# 86        paint_color_white  0.002919  0.002919
# ...

# %% [markdown]
# ### Evaluation

# %% [markdown]
#     During this practice, we developed two linear regression models using the Ridge and Lasso approaches to predict the price of a used car. We also identified the key factors that influence the price of a used car. Both models produced very similar results, highlighting odometer, year, cylinders, drive, condition, type, and fuel as important factors. The signs of the coefficients for these factors indicate whether they have a positive or negative impact on the price of a used car.
#
#     The Ridge regression model is more complex, with more features, but it has a smaller Mean Squared Error (MSE) of 0.24. On the other hand, the Lasso regression model can automatically select features and is simpler, with fewer features, but its MSE is slightly larger at 0.27.
#
#     To evaluate both models, I created plots of the predicted prices against the actual prices for the test set. The correlation between the predicted and actual prices is reasonably good for both models.
#
#     Based on these findings, I believe that I have valuable information to provide to my client.

# %% [markdown]
# ### Deployment

# %% [markdown]
#     From the analysis of a dataset containing information on 250,000 used cars, both Ridge and Lasso regression models demonstrated strong performance and can be utilized to predict the price of a used car. The factors that have a significant impact on the price of a used car include odometer reading, year, number of cylinders, drive type, condition, car type, and fuel type. Here are the key findings:
#     - Odometer: A higher mileage results in a lower car price
#     - Year: Older cars are priced lower
#     - Cylinders: Cars with more cylinders tend to be more expensive
#     - Drive: 4wd can increase the price, while fwd can decrease it
#     - Condition: A better condition increases the price
#     - Type: Trucks tend to increase the price, while sedans decrease it
#     - Fuel: Diesel tends to increase the price, while gas decreases it
#     Based on the dataset from 250K used cars, both Ridge and Lasso regression models are well performed and they can be deployed to predict the price of a used car.  Odometer, year, cylinders, drive, condition, type, fuel are important factors that determine the price of a used car. The primary findings are listed below.
